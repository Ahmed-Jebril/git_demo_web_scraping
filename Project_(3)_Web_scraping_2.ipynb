# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-Jebril/git_demo_web_scraping/blob/main/Project_(3)_Web_scraping_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrap():
  titles_all = []
  links_all = []
  occupations_all = []
  companies_all = []
  specs_all = []

  response = requests.get('https://wuzzuf.net/search/jobs/?a=hpb&q=machine%20learning&start=0')
  soup = BeautifulSoup(response.content, 'lxml')
  pages = soup.find_all("button", {'class': 'css-1dtj1k4 ezfki8j0'})
  pages_lst = [int(page.text) for page in pages]
  
  for i in range(pages_lst[-1]):
    response = requests.get('https://wuzzuf.net/search/jobs/?a=hpb&q=machine%20learning&start='+str(i))
    soup = BeautifulSoup(response.content, 'lxml')

    titles = soup.find_all("h2", {'class': 'css-m604qf'})
    titles_lst = [title.a.text for title in titles]
    titles_all = titles_all + titles_lst

    links = ['https://wuzzuf.net' + title.a['href'] for title in titles]
    links_all = links_all + links

    occupations = soup.find_all("div", {'class': 'css-1lh32fc'})
    occupations_lst = [occupation.text for occupation in occupations]
    occupations_all = occupations_all + occupations_lst

    companies = soup.find_all("a", {'class': 'css-17s97q8'})
    companies_lst = [company.text for company in companies]
    companies_all = companies_all + companies_lst

    specs = soup.find_all("div", {'class': 'css-y4udm8'})
    specs_lst = [spec.text for spec in specs]
    specs_all = specs_all + specs_lst

    scraped_data = {}
    scraped_data['Title'] = titles_all
    scraped_data['Link'] = links_all
    scraped_data['Occupation'] = occupations_all
    scraped_data['Company'] = companies_all
    scraped_data['Specs'] = specs_all

  df = pd.DataFrame(scraped_data)
  df.to_csv('mljobs.csv', index=False)
  print("Jobs Scraped Successfully")
  return df

if __name__ == '__main__':
    scrap()
# Out:
# Jobs Scraped Successfully

# %%
scrap()
# Out:
# Jobs Scraped Successfully
#                                                 Title  \
# 0                    Senior Machine Learning Engineer
# 1           Research Software Development Engineer L2
# 2                           Machine Learning Engineer
# 3                                  Software Team Lead
# 4                       Python Developer - Internship
# 5                           Senior Research Scientist
# 6                               Training Section Head
# 7                               Senior Java Developer
# 8                   Junior Embedded Software Engineer
# 9                      Data Analyst, Egypt Impact Lab
# 10              Production Technology Lead Specialist
# 11                             Outdoor Sales Engineer
# 12                              Senior Odoo Developer
# 13                 IT Technical Support - (Help Desk)
# 14                               Distribution manager
# 15  Electronics Maintenance Engineer OR Power Engi...
# 16                                HR Business Partner
# 17                            Junior Python Developer
# 18                       Application Support Engineer
# 19            QA Validation and Qualification Officer
# 20                           Administrator (Helpdesk)
# 21                            Business System Analyst
# 22              Odoo Developer & Pre-Sales Specialist
# 23                            Snowflakes DW developer
# 24                                 Software Architect
# 25                              NGenius POS Developer
# 26                                      Sales Manager
# 27                              Data Entry Specialist
# 28                                  Backend Developer
# 29                                Front End Developer
# 30      Mechanical Engineer - Pharmaceutical Industry
# 31       Full Stack Developer (.Net Core & Angular 9)
#
#                                                  Link  \
# 0   https://wuzzuf.net/jobs/p/YDxhBIJimaOR-Senior-...
# 1   https://wuzzuf.net/jobs/p/yhXbcd0M8byl-Researc...
# 2   https://wuzzuf.net/jobs/p/63GDVXe1mip9-Machine...
# 3   https://wuzzuf.net/jobs/p/tDpJrj9GeBO6-Softwar...
# 0                                         Media Sci -
# 1                                       TensorGraph -
# 2                                          Edentech -
# 3                                          TMentors -
# 4                                          TMentors -
# 5                                           Atomica -
# 6                             Giza Cable Industries -
# 7                                         Media Sci -
# 8                                         Swift Act -
# 9   National Institute for Governance and Developm...
# 10                  LEONI Wiring System Egypt S.A.E -
# 11                                            ACFET -
# 12                                      Blue Ribbon -
# 13                         Raya Customer Experience -
# 14                                              MEC -
# 15                                    01electronics -
# 16                                         EasyKash -
# 17                                              RDI -
# 18                                     Caelum Egypt -
# 19                                      APEX Pharma -
# 20                                           Raya   -
# 21                                              GS1 -
# 22                                         Elitbuzz -
# 23                                       FlairsTech -
# 24                             Perfect Presentation -
# 25                     Network International -Egypt -
# 26                                        Misr salt -
# 27                                            Botit -
# 28                                  Nile University -
# 29                                  Nile University -
# 30                      Global Napi Pharmaceuticals -
# 31                           JRM for Communications -
#
#                                                 Specs
# 0   .css-1lh32fc{display:-webkit-box;display:-webk...
# 1   Full TimeExperienced · 2 - 4 Yrs of Exp · R&D/...
# 2   Full TimeExperienced · 3 - 7 Yrs of Exp · IT/S...
# 3   Full TimeManager · 8 - 12 Yrs of Exp · IT/Soft...
# 4   InternshipStudent · IT/Software Development · ...
# 5   Full TimeExperienced · 4+ Yrs of Exp · IT/Soft...
# 6   Full TimeManager · 10 - 20 Yrs of Exp · Traini...
# 7   Full TimeWork From HomeExperienced · 5+ Yrs of...
# 8   Full TimeEntry Level · 0 - 1 Yrs of Exp · IT/S...
# 9   Full TimeExperienced · 2 - 5 Yrs of Exp · Anal...
# 10  Full TimeEntry Level · 0 - 1 Yrs of Exp · Manu...
# 11  Full TimeExperienced · 2 - 4 Yrs of Exp · Sale...
# 12  Full TimeExperienced · 5+ Yrs of Exp · IT/Soft...
# 13  Full TimeEntry Level · 0 - 1 Yrs of Exp · Inst...
# 14  Full TimeManager · 10+ Yrs of Exp · males_only...
# 15  .css-1lh32fc{display:-webkit-box;display:-webk...
# 16  Full TimePart TimeExperienced · 2 - 5 Yrs of E...
# 17  Full TimeEntry Level · 1+ Yrs of Exp · IT/Soft...
# 18  Full TimeExperienced · 2 - 4 Yrs of Exp · IT/S...
# 19  Full TimeExperienced · 3 - 5 Yrs of Exp · Qual...
# 20  Full TimeEntry Level · 1 - 2 Yrs of Exp · IT/S...
# 21  Full TimeExperienced · 2 - 5 Yrs of Exp · IT/S...
# 22  Full TimeExperienced · 5+ Yrs of Exp · IT/Soft...
# 23  Full TimeExperienced · 3 - 5 Yrs of Exp · IT/S...
# 24  Full TimeExperienced · 10+ Yrs of Exp · IT/Sof...
# 25  Full TimeExperienced · 6 - 12 Yrs of Exp · IT/...
# 26  Full TimeManager · 8+ Yrs of Exp · Operations/...
# 27  Full TimeEntry Level · 0 - 3 Yrs of Exp · Admi...
# 28  Full TimeEntry Level · 0 - 3 Yrs of Exp · IT/S...
# 29  Full TimeEntry Level · 0 - 3 Yrs of Exp · IT/S...
# 30  .css-1lh32fc{display:-webkit-box;display:-webk...
# 31  Full TimeExperienced · 2+ Yrs of Exp · IT/Soft...
